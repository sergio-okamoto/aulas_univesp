# %% [markdown]
# <a href="https://colab.research.google.com/github/sergio-okamoto/aulas_univesp/blob/main/exerciciosPython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
disciplina = "Formação profissional em Python"
qtdSemanas = 8
nota1 = 9.0
nota2 = 7.0
media = (nota1+nota2)/2
media
# Out:
# 8.0

# %%
print (nota1)
# Out:
# 9.0

# %%
def media_notas(nota1,nota2):
  return (nota1+nota2)/2

# %%
media_notas(4,10)
# Out:
# 7.0

# %%
def exercicio1():
    palavra = input("Digite uma palavra: ")
    lista = list(palavra)
    segredo=""
    for x in lista:
        if (x == 'z'): segredo+='a'
        elif (x == 'Z'): segedo+='A'
        else: segredo+=chr(ord(x)+1)
    print(segredo)

# %%
exercicio1()
# Out:
# Digite uma palavra: UNIVESP
# VOJWFTQ

# %%
exercicio1()
# Out:
# Digite uma palavra: univesp
# vojwftq

# %%
exercicio1()
# Out:
# Digite uma palavra: Univesp
# Vojwftq

# %%
import pandas as pd
uri = "https://raw.githubusercontent.com/fivethirtyeight/data/master/alcohol-consumption/drinks.csv"
bebidas = pd.read_csv(uri, error_bad_lines = False, encoding='latin 1')
bebidas.head()
# Out:
#        country  beer_servings  ...  wine_servings  total_litres_of_pure_alcohol
# 0  Afghanistan              0  ...              0                           0.0
# 1      Albania             89  ...             54                           4.9
# 2      Algeria             25  ...             14                           0.7
# 3      Andorra            245  ...            312                          12.4
# 4       Angola            217  ...             45                           5.9
#
# [5 rows x 5 columns]

# %%
bebidas.columns = ["pais", "cerveja", "destilado", "vinho", "total de litros"]
bebidas.head()
# Out:
#           pais  cerveja  destilado  vinho  total de litros
# 0  Afghanistan        0          0      0              0.0
# 1      Albania       89        132     54              4.9
# 2      Algeria       25          0     14              0.7
# 3      Andorra      245        138    312             12.4
# 4       Angola      217         57     45              5.9

# %%
bebidas["cerveja"].describe()
# Out:
# count    193.000000
# mean     106.160622
# std      101.143103
# min        0.000000
# 25%       20.000000
# 50%       76.000000
# 75%      188.000000
# max      376.000000
# Name: cerveja, dtype: float64

# %%
bebidas.describe()
# Out:
#           cerveja   destilado       vinho  total de litros
# count  193.000000  193.000000  193.000000       193.000000
# mean   106.160622   80.994819   49.450777         4.717098
# std    101.143103   88.284312   79.697598         3.773298
# min      0.000000    0.000000    0.000000         0.000000
# 25%     20.000000    4.000000    1.000000         1.300000
# 50%     76.000000   56.000000    8.000000         4.200000
# 75%    188.000000  128.000000   59.000000         7.200000
# max    376.000000  438.000000  370.000000        14.400000

# %%
bebidas.plot(kind='hist')

# %%
bebidas.median().plot()
